# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
file_path = '../data/18109003_excelRawData.csv'

df = pd.read_csv(file_path, index_col=0)
df.head()

start_column = 0
cutoff_column = 150

#defined start and cutoff_columns to tell program to only measure peak of first EPSP
#only want to measure first EPSP bc second was to experiment with channels' kinetics

df = df[start_column:cutoff_column]
df.head()
# Out:
#                   1         2         3         4         5         6  \
# Time (ms)
# 0.0        0.000106  0.007619 -0.012782  0.001895 -0.007339  0.004437
# 0.1        0.003819  0.012858 -0.010900  0.002251 -0.000574  0.007540
# 0.2        0.002293  0.014384 -0.008764  0.001641  0.002478  0.006014
# 0.3       -0.004370  0.010162 -0.008408  0.000776  0.001613  0.000572
# 0.4       -0.008388  0.005839 -0.005407 -0.000800 -0.000574 -0.002836
#
#                   7         8         9        10    ...          111  \
# Time (ms)                                            ...
# 0.0       -0.001141 -0.005963  0.002096 -0.008308    ...     0.005777
# 0.1       -0.004447 -0.008659  0.002452 -0.009783    ...     0.005828
# 0.2       -0.008109 -0.009879  0.006419 -0.012530    ...     0.004607
# 0.3       -0.010195 -0.012270  0.007996 -0.012174    ...     0.000081
# 0.4       -0.010856 -0.011710  0.005809 -0.008257    ...    -0.004548
#
# ...

# %%
df.describe()
# Out:
#                  1            2            3            4            5  \
# count  1501.000000  1501.000000  1501.000000  1501.000000  1501.000000
# mean     -0.007072    -0.004988    -0.004962    -0.008418    -0.007652
# std       0.020945     0.020728     0.020525     0.019660     0.020148
# min      -0.171352    -0.171163    -0.162166    -0.160509    -0.170658
# 25%      -0.011491    -0.009267    -0.008713    -0.013313    -0.012628
# 50%      -0.004574    -0.002554    -0.002711    -0.006192    -0.004694
# 75%       0.002039     0.003957     0.004358     0.000573     0.001105
# max       0.042017     0.029337     0.031875     0.025495     0.025061
#
#                  6            7            8            9           10  \
# count  1501.000000  1501.000000  1501.000000  1501.000000  1501.000000
# mean     -0.005817    -0.005208    -0.006024    -0.003615    -0.005724
# std       0.020033     0.019357     0.018694     0.020131     0.019621
# ...

# %%
plt.plot(df.index, df[['1']])
plt.show()

# %%
df.describe()
# Out:
#                  1            2            3            4            5  \
# count  1501.000000  1501.000000  1501.000000  1501.000000  1501.000000
# mean     -0.007072    -0.004988    -0.004962    -0.008418    -0.007652
# std       0.020945     0.020728     0.020525     0.019660     0.020148
# min      -0.171352    -0.171163    -0.162166    -0.160509    -0.170658
# 25%      -0.011491    -0.009267    -0.008713    -0.013313    -0.012628
# 50%      -0.004574    -0.002554    -0.002711    -0.006192    -0.004694
# 75%       0.002039     0.003957     0.004358     0.000573     0.001105
# max       0.042017     0.029337     0.031875     0.025495     0.025061
#
#                  6            7            8            9           10  \
# count  1501.000000  1501.000000  1501.000000  1501.000000  1501.000000
# mean     -0.005817    -0.005208    -0.006024    -0.003615    -0.005724
# std       0.020033     0.019357     0.018694     0.020131     0.019621
# ...

# %%
df[['1']].min()
# Out:
# 1   -0.171352
# dtype: float64

# %%
df.min()
# Out:
# 1     -0.171352
# 2     -0.171163
# 3     -0.162166
# 4     -0.160509
# 5     -0.170658
# 6     -0.177091
# 7     -0.145642
# 8     -0.146801
# 9     -0.165191
# 10    -0.157387
# 11    -0.170259
# 12    -0.161593
# 13    -0.170720
# 14    -0.162597
# 15    -0.167569
# 16    -0.166610
# 17    -0.176007
# 18    -0.163348
# 19    -0.162529
# 20    -0.174509
# 21    -0.167924
# 22    -0.167840
# 23    -0.164746
# 24    -0.167574
# 25    -0.165843
# 26    -0.133251
# 27    -0.102021
# 28    -0.086885
# 29    -0.099094
# 30    -0.096831
#          ...
# 91    -0.136064
# 92    -0.137559
# 93    -0.143429
# 94    -0.146003
# 95    -0.152808
# 96    -0.144163
# 97    -0.151914
# 98    -0.154640
# 99    -0.183636
# 100   -0.158361
# 101   -0.156167
# 102   -0.170994
# 103   -0.151172
# 104   -0.178302
# 105   -0.173690
# 106   -0.173950
# 107   -0.159741
# 108   -0.181673
# 109   -0.176243
# 110   -0.186856
# 111   -0.149303
# 112   -0.078112
# 113   -0.029943
# 114   -0.029909
# ...

# %%
min_values = pd.DataFrame({'min': df.min()}).reset_index() 
min_values.head()
# Out:
#   index       min
# 0     1 -0.171352
# 1     2 -0.171163
# 2     3 -0.162166
# 3     4 -0.160509
# 4     5 -0.170658

# %%
min_values.plot(x = 'index', y = 'min')
